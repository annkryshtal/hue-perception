# %%
def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt
file_location = "hueak.xlsx"

workbook = xlrd.open_workbook(file_location)

first_sheet = workbook.sheet_by_index(0)

# print(first_sheet)

x = [first_sheet.cell_value(i, 5) for i in range(1,16,1)]
y = [first_sheet.cell_value(i, 7) for i in range(1,16,1)]



# print(x, y)
plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x, y, 'o', label='akryshtal')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average ak')
plt.legend()
plt.savefig('0_ak.png')
plt.show()

# %%
file_location1 = "hueysu.xlsx"

workbook1 = xlrd.open_workbook(file_location1)

first_sheet1 = workbook1.sheet_by_index(0)

k = [first_sheet1.cell_value(i, 5) for i in range(1,16,1)]
z = [first_sheet1.cell_value(i, 7) for i in range(1,16,1)]



plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(k,z, 'o', label='ysu')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average ysu')
plt.legend()
plt.savefig('0_ysu.png')
plt.show()

# %%
file_location2 = "huembe.xlsx"

workbook2 = xlrd.open_workbook(file_location2)

first_sheet2 = workbook2.sheet_by_index(0)


l = [first_sheet2.cell_value(i, 5) for i in range(1,16,1)]
p = [first_sheet2.cell_value(i, 7) for i in range(1,16,1)]



plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(l,p, 'o', label='mbengala')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average mbe')
plt.legend()
plt.savefig('0_mbe.png')
plt.show()

# %%
file_location3 = "huekb.xlsx"

workbook3 = xlrd.open_workbook(file_location3)

first_sheet3 = workbook3.sheet_by_index(0)

s = [first_sheet3.cell_value(i, 6) for i in range(1,16,1)]
t = [first_sheet3.cell_value(i, 5) for i in range(1,16,1)]



plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(s,t, 'o', label='kbracher')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average kb')
plt.legend()
plt.savefig('0_kb.png')
plt.show()

# %%
file_location4 = "huemba.xlsx"

workbook4 = xlrd.open_workbook(file_location4)

first_sheet4 = workbook4.sheet_by_index(0)


j = [first_sheet4.cell_value(i, 5) for i in range(1,16,1)]
m = [first_sheet4.cell_value(i, 7) for i in range(1,16,1)]




plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(j, m, 'o', label='mbayer')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average mba')
plt.legend()
plt.savefig('0_mba.png')
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.axis([-5,360,0,10])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x, y,'o', label='akryshtal')
plt.plot(k,z, 'o', label='ysu')
plt.plot(l,p, 'o', label='mbengala')
plt.plot(s,t, 'o', label='kbracher')
plt.plot(j, m, 'o', label='mbayer')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('All subjects with 0 noise average')
plt.legend()
plt.savefig('all_0_av.png')
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.axis([-5,360,0,10])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x, y,'o', label='akryshtal', color = 'blue')
plt.plot(k,z, 'o', label='ysu', color = 'blue')
plt.plot(l,p, 'o', label='mbengala', color = 'blue')
plt.plot(s,t, 'o', label='kbracher', color = 'blue')
plt.plot(j, m, 'o', label='mbayer', color = 'blue')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('All subjects with 0 noise average')
plt.legend()
plt.savefig('all_0_10_av.png')
plt.show()
