# %%
def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

# %%
#Code example for #1
import xlrd
import numpy as np
import matplotlib.pyplot as plt

file_location1 = "hueysu.xlsx"

workbook1 = xlrd.open_workbook(file_location1)

first_sheet1 = workbook1.sheet_by_index(0)
# 0 noise
a = [360]*12
k = [first_sheet1.cell_value(i, 2) for i in range(1,176,1)] + a
z = [first_sheet1.cell_value(i, 3) for i in range(1,176,1)] + [first_sheet1.cell_value(i, 3) for i in range(81,93,1)] 

k1 = [first_sheet1.cell_value(i, 5) for i in range(1,18,1)]
z1 = [first_sheet1.cell_value(i, 6) for i in range(1,18,1)]
er41 = [first_sheet1.cell_value(i, 8) for i in range(1,18,1)]
k1, z1, er41 = (list(i) for i in zip(*sorted(zip(k1, z1, er41))))

# 10 noise
k2 = [first_sheet1.cell_value(i, 2) for i in range(178, 369,1)] + a
z2 = [first_sheet1.cell_value(i, 3) for i in range(178, 369,1)] + [first_sheet1.cell_value(i, 3) for i in range(274, 286,1)] 

k3 = [first_sheet1.cell_value(i, 5) for i in range(178,195,1)]
z3 = [first_sheet1.cell_value(i, 6) for i in range(178,195,1)]
er42 = [first_sheet1.cell_value(i, 8) for i in range(178,195,1)]
k3, z3, er42 = (list(i) for i in zip(*sorted(zip(k3, z3, er42))))


o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
x11=[22.5,45]
x33=[67.5, 247.5,337.5]
x22= [-4.34,-3.85]
x44=[-5.52,-3.23,4.08]
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.plot(k,z,'o',label='ysu 0', alpha=0.5)
ax1.errorbar(k1, z1, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 0 av')
ax1.scatter(x11,x22,s=200,marker='x',color = 'red', zorder=5)
ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')
#ax1.title('0 noise')
ax1.legend()


ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.plot(k2,z2,'o',label='ysu 10', alpha=0.5)
ax2.errorbar(k3, z3, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 10 av')
ax2.scatter(x33,x44,s=200,marker='x',color = 'red', zorder=5)
ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')
#ax2.title('0 noise')
ax2.legend()

plt.savefig('0_10_av+data_ysu_se.png')
plt.show()

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt
file_location = "hue.xlsx"

workbook = xlrd.open_workbook(file_location)

first_sheet = workbook.sheet_by_index(1)

a = [360]*12
x = [first_sheet.cell_value(i, 2) for i in range(1,191,1)] + a
y = [first_sheet.cell_value(i, 3) for i in range(1,191,1)] + [first_sheet.cell_value(i, 3) for i in range(97,109,1)]

file_location = "hueak.xlsx"
workbook = xlrd.open_workbook(file_location)
first_sheet1 = workbook.sheet_by_index(0)


x1 = [first_sheet1.cell_value(i, 5) for i in range(1,18,1)]
y1 = [first_sheet1.cell_value(i, 6) for i in range(1,18,1)]
er = [first_sheet1.cell_value(i, 8) for i in range(1,18,1)]
x1, y1, er = (list(t) for t in zip(*sorted(zip(x1, y1, er))))


# 10 noise
x2 = [first_sheet.cell_value(i, 2) for i in range(193,383,1)] + a
y2 = [first_sheet.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet.cell_value(i, 3) for i in range(288,300,1)]

x3 = [first_sheet1.cell_value(i, 5) for i in range(192,209,1)]
y3 = [first_sheet1.cell_value(i, 6) for i in range(192,209,1)]
er1 = [first_sheet1.cell_value(i, 8) for i in range(192,209,1)]
x3, y3, er1 = (list(t) for t in zip(*sorted(zip(x3, y3, er1))))


o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
x11=[67.5,225]
x33=[22.5,67.5, 247.5,292.5,45,180]
x22= [-2.87,-3.95]
x44=[-4.3,-3.9,3.7,3.5,-5.2,-7.75]
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.plot(x,y,'o',label='ak 0', alpha=0.5)
ax1.errorbar(x1, y1, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 0 av')
ax1.scatter(x11,x22,s=200,marker='x',color = 'red', zorder=5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')
#ax1.title('0 noise')
ax1.legend()

ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.plot(x2,y2,'o',label='ak 10', alpha=0.5)
ax2.errorbar(x3, y3, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 10 av')
ax2.scatter(x33,x44,s=200,marker='x',color = 'red', zorder=5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')
#ax2.title('0 noise')
ax2.legend()

plt.savefig('0_10_av+data_ak_se.png')
plt.show()

# %%
#Code example for #1
import xlrd
import numpy as np
import matplotlib.pyplot as plt

file_location2 = "huembe.xlsx"
workbook2 = xlrd.open_workbook(file_location2)

first_sheet2 = workbook2.sheet_by_index(0)



yerr_pos = [first_sheet2.cell_value(i, 2) for i in range(first_sheet2.ncols)]
yerr_neg = [first_sheet2.cell_value(i, 3) for i in range(first_sheet2.ncols)]

# 0 noise
b = [360]*12
l = [first_sheet2.cell_value(i, 2) for i in range(1,190,1)] + a
p = [first_sheet2.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet2.cell_value(i, 3) for i in range(97,109,1)]

l1 = [first_sheet2.cell_value(i, 5) for i in range(1,18,1)]
p1 = [first_sheet2.cell_value(i, 6) for i in range(1,18,1)]
er21 = [first_sheet2.cell_value(i, 8) for i in range(1,18,1)]
l1, p1, er21 = (list(t) for t in zip(*sorted(zip(l1, p1, er21))))

# 10 noise
l2 = [first_sheet2.cell_value(i, 2) for i in range(193,383,1)] + b
p2 = [first_sheet2.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet2.cell_value(i, 3) for i in range(288,300,1)]

l3 = [first_sheet2.cell_value(i, 5) for i in range(192,209,1)]
p3 = [first_sheet2.cell_value(i, 6) for i in range(192,209,1)]
er22 = [first_sheet2.cell_value(i, 8) for i in range(192,209,1)]
l3, p3, er22 = (list(t) for t in zip(*sorted(zip(l3, p3, er22))))


o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
x11=[22.5,45,90]
x33=[157.5,270]
x22= [-6.63,-6.2,-3.53]
x44=[4.55,-3.42]
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.plot(l,p,'o',label='mbe 0', alpha=0.5)
ax1.errorbar(l1, p1, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 0 av')
ax1.scatter(x11,x22,s=200,marker='x',color = 'red', zorder=5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')
#ax1.title('0 noise')
ax1.legend()

ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.plot(l2,p2,'o',label='mbe 10', alpha=0.5)
ax2.errorbar(l3, p3, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 10 av')
ax2.scatter(x33,x44,s=200,marker='x',color = 'red', zorder=5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')
#ax2.title('0 noise')
ax2.legend()

plt.savefig('0_10_av+data_mbe_se.png')
plt.show()

# %%
#Code example for #1
import xlrd
import numpy as np
import matplotlib.pyplot as plt

file_location4 = "huemba.xlsx"

workbook4 = xlrd.open_workbook(file_location4)

first_sheet4 = workbook4.sheet_by_index(0)

# 0 noise
b = [360]*12
j = [first_sheet4.cell_value(i, 2) for i in range(1,190,1)] + a
m = [first_sheet4.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet4.cell_value(i, 3) for i in range(97,109,1)]

j1 = [first_sheet4.cell_value(i, 5) for i in range(1,18,1)]
m1 = [first_sheet4.cell_value(i, 6) for i in range(1,18,1)]
er11 = [first_sheet4.cell_value(i, 8) for i in range(1,18,1)]
j1, m1, er11 = (list(t) for t in zip(*sorted(zip(j1, m1, er11))))

# 10 noise
j2 = [first_sheet4.cell_value(i, 2) for i in range(193,383,1)] + b
m2= [first_sheet4.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet4.cell_value(i, 3) for i in range(288,300,1)]

j3 = [first_sheet4.cell_value(i, 5) for i in range(192,209,1)]
m3 = [first_sheet4.cell_value(i, 6) for i in range(192,209,1)]
er12 = [first_sheet4.cell_value(i, 8) for i in range(192,209,1)]
j3, m3, er12 = (list(t) for t in zip(*sorted(zip(j3, m3, er12))))


o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
x11=[337.5]
x33=[112.5,202.5,0,360]
x22= [3]
x44=[3.1,5.95,4.83,4.83]
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.plot(j,m,'o',label='mba 0', alpha=0.5)
ax1.errorbar(j1, m1, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 0 av')
ax1.scatter(x11,x22,s=200,marker='x',color = 'red', zorder=5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')
#ax1.title('0 noise')
ax1.legend()

ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.plot(j2,m2,'o',label='mba 10', alpha=0.5)
ax2.errorbar(j3, m3, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 10 av')
ax2.scatter(x33,x44,s=200,marker='x',color = 'red', zorder=5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')
#ax2.title('0 noise')
ax2.legend()

plt.savefig('0_10_av+data_mba_se.png')
plt.show()

# %%
#Code example for #1
file_location3 = "huekb.xlsx"
workbook3 = xlrd.open_workbook(file_location3)
first_sheet3 = workbook3.sheet_by_index(0)

# 0 noise
b = [360]*12
s = [first_sheet3.cell_value(i, 2) for i in range(1,190,1)] + b
t = [first_sheet3.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet3.cell_value(i, 3) for i in range(1,13,1)] 

s1 = [first_sheet3.cell_value(i, 6) for i in range(1,18,1)]
t1 = [first_sheet3.cell_value(i, 7) for i in range(1,18,1)]
er31 = [first_sheet3.cell_value(i, 8) for i in range(1,18,1)]
s1, t1, er31 = (list(i) for i in zip(*sorted(zip(s1, t1, er31))))

# 10 noise
c = [360]*11
s2 = [first_sheet3.cell_value(i, 2) for i in range(193,383,1)] + a
t2= [first_sheet3.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet3.cell_value(i, 3) for i in range(289,301,1)]

s3 = [first_sheet3.cell_value(i, 6) for i in range(193,210,1)]
t3 = [first_sheet3.cell_value(i, 7) for i in range(193,210,1)]
er32 = [first_sheet3.cell_value(i, 8) for i in range(193,210,1)]
s3, t3, er32 = (list(i) for i in zip(*sorted(zip(s3, t3, er32))))


o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
x11=[22.5,180,202.5]
x33=[45,180,202.5]
x22= [-2.88,4.2,3.4]
x44=[3.25,2.88,4.2]
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.plot(s,t,'o',label='kb 0', alpha=0.5)
ax1.errorbar(s1, t1, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 0 av')
ax1.scatter(x11,x22,s=200,marker='x',color = 'red', zorder=5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')
#ax1.title('0 noise')
ax1.legend()

ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray')
ax2.plot(s2,t2,'o',label='kb 10', alpha=0.5)
ax2.errorbar(s3, t3, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 10 av')
ax2.scatter(x33,x44,s=200,marker='x',color = 'red', zorder=5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')
#ax2.title('0 noise')
ax2.legend()

plt.savefig('0_10_av+data_kb_se.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,95,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(s1, t1, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 0 av', alpha=0.5)
ax1.errorbar(j1, m1, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 0 av', alpha=0.5)
ax1.errorbar(l1, p1, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 0 av', alpha=0.5)
ax1.errorbar(x1, y1, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 0 av', alpha=0.5)
ax1.errorbar(k1, z1, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 0 av', alpha=0.5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([-5,95,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(s3, t3, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 10 av', alpha=0.5)
ax2.errorbar(j3, m3, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 10 av', alpha=0.5)
ax2.errorbar(l3, p3, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 10 av', alpha=0.5)
ax2.errorbar(x3, y3, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 10 av', alpha=0.5)
ax2.errorbar(k3, z3, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 10 av', alpha=0.5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_av+data_1_se.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(s1, t1, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 0 av', alpha=0.5)
ax1.errorbar(j1, m1, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 0 av', alpha=0.5)
ax1.errorbar(l1, p1, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 0 av', alpha=0.5)
ax1.errorbar(x1, y1, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 0 av', alpha=0.5)
ax1.errorbar(k1, z1, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 0 av', alpha=0.5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([-5,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(s3, t3, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 10 av', alpha=0.5)
ax2.errorbar(j3, m3, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 10 av', alpha=0.5)
ax2.errorbar(l3, p3, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 10 av', alpha=0.5)
ax2.errorbar(x3, y3, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 10 av', alpha=0.5)
ax2.errorbar(k3, z3, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 10 av', alpha=0.5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_av+data_2_se__.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([0, 185,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(s1, t1, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 0 av', alpha=0.5)
ax1.errorbar(j1, m1, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 0 av', alpha=0.5)
ax1.errorbar(l1, p1, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 0 av', alpha=0.5)
ax1.errorbar(x1, y1, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 0 av', alpha=0.5)
ax1.errorbar(k1, z1, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 0 av', alpha=0.5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([0, 185, -15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(s3, t3, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 10 av', alpha=0.5)
ax2.errorbar(j3, m3, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 10 av', alpha=0.5)
ax2.errorbar(l3, p3, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 10 av', alpha=0.5)
ax2.errorbar(x3, y3, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 10 av', alpha=0.5)
ax2.errorbar(k3, z3, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 10 av', alpha=0.5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_av+data_3_se__.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([185,365,-15,15])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(s1, t1, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 0 av', alpha=0.5)
ax1.errorbar(j1, m1, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 0 av', alpha=0.5)
ax1.errorbar(l1, p1, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 0 av', alpha=0.5)
ax1.errorbar(x1, y1, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 0 av', alpha=0.5)
ax1.errorbar(k1, z1, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 0 av', alpha=0.5)

ax1.set_ylabel('delta, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([185,365,-15,15])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(s3, t3, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, label='kb 10 av', alpha=0.5)
ax2.errorbar(j3, m3, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mba 10 av', alpha=0.5)
ax2.errorbar(l3, p3, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3, label='mbe 10 av', alpha=0.5)
ax2.errorbar(x3, y3, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ak 10 av', alpha=0.5)
ax2.errorbar(k3, z3, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, label='ysu 10 av', alpha=0.5)

ax2.set_ylabel('delta, °')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_av+data_4_se_.png')
plt.show()
