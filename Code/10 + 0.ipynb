# %%
def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt
file_location = "hueak.xlsx"

workbook = xlrd.open_workbook(file_location)

first_sheet = workbook.sheet_by_index(0)

# print(first_sheet)

x = [first_sheet.cell_value(i, 5) for i in range(1,18,1)]
y = [first_sheet.cell_value(i, 7) for i in range(1,18,1)]
er = [first_sheet.cell_value(i, 8) for i in range(1,18,1)]
x, y, er = (list(t) for t in zip(*sorted(zip(x, y, er))))



# print(x, y)
plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.errorbar(x, y, yerr=er, fmt='-o', label='akryshtal')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average ak')
plt.legend()
#plt.savefig('0_ak.png')
plt.show()

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt
file_location = "hueak.xlsx"

workbook = xlrd.open_workbook(file_location)

first_sheet = workbook.sheet_by_index(0)

# print(first_sheet)

x1 = [first_sheet.cell_value(i, 5) for i in range(192,209,1)]
y1 = [first_sheet.cell_value(i, 7) for i in range(192,209,1)]
er1 = [first_sheet.cell_value(i, 8) for i in range(192,209,1)]
x1, y1, er1 = (list(t) for t in zip(*sorted(zip(x1, y1, er1))))


plt.figure(figsize=(10, 7))
# print(x, y)
plt.axis([-5,365,0,8])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(x, y, '--o',label='akryshtal 0', alpha=0.7)
plt.plot(x1, y1, '--o', label='akryshtal 10', alpha=0.7)

# plt.errorbar(x, y, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 0', alpha=0.7)
# plt.errorbar(x1, y1, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 10', alpha=0.7)
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise average ak')
plt.legend()
plt.savefig('__0_10_ak.png')
plt.show()

# %%
file_location1 = "hueysu.xlsx"

workbook1 = xlrd.open_workbook(file_location1)

first_sheet1 = workbook1.sheet_by_index(0)

k = [first_sheet1.cell_value(i, 5) for i in range(1,18,1)]
z = [first_sheet1.cell_value(i, 7) for i in range(1,18,1)]
er41 = [first_sheet.cell_value(i, 8) for i in range(1,18,1)]
k, z, er41 = (list(t) for t in zip(*sorted(zip(k, z, er41))))

plt.figure(figsize=(10, 7))
plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(k,z, '-o', label='ysu')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average ysu')
plt.legend()
# plt.savefig('0_ysu.png')
plt.show()

# %%
file_location1 = "hueysu.xlsx"

workbook1 = xlrd.open_workbook(file_location1)

first_sheet1 = workbook1.sheet_by_index(0)

k1 = [first_sheet1.cell_value(i, 5) for i in range(178,195,1)]
z1 = [first_sheet1.cell_value(i, 7) for i in range(178,195,1)]
er42 = [first_sheet1.cell_value(i, 8) for i in range(178,195,1)]
k1, z1, er42 = (list(t) for t in zip(*sorted(zip(k1, z1, er42))))


plt.figure(figsize=(10, 7))
plt.axis([-5,365,0,8])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(k, z, '--o',alpha=0.7, label='ysu 0')
plt.plot(k1, z1, '--o',alpha=0.7, label='ysu 10')

# plt.errorbar(k, z, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 0')
# plt.errorbar(k1, z1, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 10')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise average ysu')
plt.legend()
plt.savefig('__0_10_ysu.png')
plt.show()

# %%
file_location2 = "huembe.xlsx"

workbook2 = xlrd.open_workbook(file_location2)

first_sheet2 = workbook2.sheet_by_index(0)


l = [first_sheet2.cell_value(i, 5) for i in range(1,18,1)]
p = [first_sheet2.cell_value(i, 7) for i in range(1,18,1)]
er21 = [first_sheet2.cell_value(i, 8) for i in range(1,18,1)]
l, p, er21 = (list(t) for t in zip(*sorted(zip(l, p, er21))))


plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(l,p, 'o', label='mbengala')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average mbe')
plt.legend()
plt.savefig('0_mbe.png')
plt.show()

# %%
file_location2 = "huembe.xlsx"

workbook2 = xlrd.open_workbook(file_location2)

first_sheet2 = workbook2.sheet_by_index(0)


l1 = [first_sheet2.cell_value(i, 5) for i in range(192,209,1)]
er22 = [first_sheet2.cell_value(i, 8) for i in range(192,209,1)]
p1 = [first_sheet2.cell_value(i, 7) for i in range(192,209,1)]
l1, p1, er22 = (list(t) for t in zip(*sorted(zip(l1, p1, er22))))


plt.figure(figsize=(10, 7))
plt.axis([-5,365,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(l, p,'--o',  alpha=0.7, label='mbe 0 av')
plt.plot(l1, p1,'--o',  alpha=0.7, label='mbe 10 av')

# plt.errorbar(l, p, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 0 av')
# plt.errorbar(l1, p1, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 10 av')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise average mbe')
plt.legend()
plt.savefig('__0_10_mbe.png')
plt.show()

# %%
file_location3 = "huekb.xlsx"

workbook3 = xlrd.open_workbook(file_location3)

first_sheet3 = workbook3.sheet_by_index(0)

s = [first_sheet3.cell_value(i, 6) for i in range(1,18,1)]
t = [first_sheet3.cell_value(i, 5) for i in range(1,18,1)]
er31 = [first_sheet3.cell_value(i, 8) for i in range(1,18,1)]

s, t, er31 = (list(i) for i in zip(*sorted(zip(s, t, er31))))



plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(s,t, 'o', label='kbracher')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average kb')
plt.legend()
# plt.savefig('0_kb.png')
plt.show()

# %%
file_location3 = "huekb.xlsx"

workbook3 = xlrd.open_workbook(file_location3)

first_sheet3 = workbook3.sheet_by_index(0)

s1 = [first_sheet3.cell_value(i, 6) for i in range(193,210,1)]
t1 = [first_sheet3.cell_value(i, 5) for i in range(193,210,1)]
er32 = [first_sheet3.cell_value(i, 8) for i in range(193,210,1)]

s1, t1, er32 = (list(i) for i in zip(*sorted(zip(s1, t1, er32))))


plt.figure(figsize=(10, 7))
plt.axis([-5,365,0,8])

# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(s, t,'--o', alpha=0.7, label='kb 0 av')
plt.plot(s1, t1,'--o', alpha=0.7, label='kb 10 av')
# plt.errorbar(s, t, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 0 av')
# plt.errorbar(s1, t1, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 10 av')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise average kb')
plt.legend()
plt.savefig('__0_10_kb.png')
plt.show()

# %%
file_location4 = "huemba.xlsx"

workbook4 = xlrd.open_workbook(file_location4)

first_sheet4 = workbook4.sheet_by_index(0)


j = [first_sheet4.cell_value(i, 5) for i in range(1,18,1)]
m = [first_sheet4.cell_value(i, 7) for i in range(1,18,1)]
er11 = [first_sheet4.cell_value(i, 8) for i in range(1,18,1)]
j, m, er11 = (list(i) for i in zip(*sorted(zip(j, m, er11))))




plt.axis([-5,360,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(j, m, 'o', label='mbayer')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 noise average mba')
plt.legend()
# plt.savefig('0_mba.png')
plt.show()

# %%
file_location4 = "huemba.xlsx"

workbook4 = xlrd.open_workbook(file_location4)

first_sheet4 = workbook4.sheet_by_index(0)


j1 = [first_sheet4.cell_value(i, 5) for i in range(192,209,1)]
m1 = [first_sheet4.cell_value(i, 7) for i in range(192,209,1)]
er12 = [first_sheet4.cell_value(i, 8) for i in range(192,209,1)]
j1, m1, er12 = (list(i) for i in zip(*sorted(zip(j1, m1, er12))))



plt.figure(figsize=(10, 7))
plt.axis([-5,365,0,10])
# plt.plot(x,y,'o')
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray', alpha=0.5)
plt.plot(o1,o, color = 'gray', alpha=0.5)
plt.plot(o2,o, color = 'gray', alpha=0.5)
plt.plot(o3,o, color = 'gray', alpha=0.5)
plt.plot(o4,o, color = 'gray', alpha=0.5)
plt.plot(o5,o, color = 'gray', alpha=0.5)
plt.plot(o6,o, color = 'gray', alpha=0.5)
plt.plot(o7,o, color = 'gray', alpha=0.5)
plt.plot(o8,o, color = 'gray', alpha=0.5)
plt.plot(o9,o, color = 'gray', alpha=0.5)
plt.plot(j, m, '--o', alpha=0.7, label='mba 0 av')
plt.plot(j1, m1, '--o', alpha=0.7, label='mba 10 av')
# plt.errorbar(j, m, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 0 av')
# plt.errorbar(j1, m1, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 10 av')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise average mba')
plt.legend()
plt.savefig('__0_10_mba.png')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.axis([-5,360,0,10])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x, y,'--o', label='akryshtal 0', color = 'blue')
plt.plot(k,z, '--o', label='ysu 0', color = 'blue')
plt.plot(l,p, '--o', label='mbengala 0', color = 'blue')
plt.plot(s,t, '--o', label='kbracher 0', color = 'blue')
plt.plot(j, m, '--o', label='mbayer 0', color = 'blue')
plt.plot(x1, y1,'--o', label='akryshtal 10', color = 'orange')
plt.plot(k1,z1, '--o', label='ysu 10', color = 'orange')
plt.plot(l1,p1, '--o', label='mbengala 10', color = 'orange')
plt.plot(s1,t1, '--o', label='kbracher 10', color = 'orange')
plt.plot(j1, m1, '--o', label='mbayer 10', color = 'orange')
plt.ylabel('SD, °')
plt.xlabel('angles, °')
plt.title('All subjects with 0 + 10 noise average')
plt.legend()
plt.savefig('___all_0_10_av.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([-5,95,0,12])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(x, y, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 0', alpha=0.7)
ax1.errorbar(k, z, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 0')
ax1.errorbar(l, p, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 0 av')
ax1.errorbar(s, t, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 0 av')
ax1.errorbar(j, m, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 0 av')

ax1.set_ylabel('SD, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([-5,95,0,12])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(x1, y1, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 10', alpha=0.7)
ax2.errorbar(k1, z1, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 10')
ax2.errorbar(l1, p1, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 10 av')
ax2.errorbar(s1, t1, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 10 av')
ax2.errorbar(j1, m1, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 10 av')
ax2.set_ylabel('SD,°')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_sd_1.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([95,185,0,12])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(x, y, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 0', alpha=0.7)
ax1.errorbar(k, z, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 0')
ax1.errorbar(l, p, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 0 av')
ax1.errorbar(s, t, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 0 av')
ax1.errorbar(j, m, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 0 av')

ax1.set_ylabel('SD, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([95,185,0,12])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(x1, y1, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 10', alpha=0.7)
ax2.errorbar(k1, z1, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 10')
ax2.errorbar(l1, p1, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 10 av')
ax2.errorbar(s1, t1, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 10 av')
ax2.errorbar(j1, m1, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 10 av')
ax2.set_ylabel('SD,°')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_sd_2.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([185,275,0,12])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(x, y, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 0', alpha=0.7)
ax1.errorbar(k, z, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 0')
ax1.errorbar(l, p, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 0 av')
ax1.errorbar(s, t, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 0 av')
ax1.errorbar(j, m, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 0 av')

ax1.set_ylabel('SD, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([185,275, 0,12])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(x1, y1, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 10', alpha=0.7)
ax2.errorbar(k1, z1, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 10')
ax2.errorbar(l1, p1, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 10 av')
ax2.errorbar(s1, t1, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 10 av')
ax2.errorbar(j1, m1, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 10 av')
ax2.set_ylabel('SD,°')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_sd_3.png')
plt.show()

# %%
#Code example for #1

o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
fig, (ax1, ax2) = plt.subplots(figsize=(13,6), ncols=2, constrained_layout=True)
ax1.axis([275,365,0,12])
ax1.plot(g, h, color = 'gray', alpha=0.5)
ax1.plot(o1,o, color = 'gray', alpha=0.5)
ax1.plot(o2,o, color = 'gray', alpha=0.5)
ax1.plot(o3,o, color = 'gray', alpha=0.5)
ax1.plot(o4,o, color = 'gray', alpha=0.5)
ax1.plot(o5,o, color = 'gray', alpha=0.5)
ax1.plot(o6,o, color = 'gray', alpha=0.5)
ax1.plot(o7,o, color = 'gray', alpha=0.5)
ax1.plot(o8,o, color = 'gray', alpha=0.5)
ax1.plot(o9,o, color = 'gray', alpha=0.5)
ax1.errorbar(x, y, yerr=er, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 0', alpha=0.7)
ax1.errorbar(k, z, yerr=er41, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 0')
ax1.errorbar(l, p, yerr=er21, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 0 av')
ax1.errorbar(s, t, yerr=er31, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 0 av')
ax1.errorbar(j, m, yerr=er11, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 0 av')

ax1.set_ylabel('SD, °')
ax1.set_xlabel('angles, °')

ax1.legend()

ax2.axis([275,365, 0,12])
ax2.plot(g, h, color = 'gray', alpha=0.5)
ax2.plot(o1,o, color = 'gray', alpha=0.5)
ax2.plot(o2,o, color = 'gray', alpha=0.5)
ax2.plot(o3,o, color = 'gray', alpha=0.5)
ax2.plot(o4,o, color = 'gray', alpha=0.5)
ax2.plot(o5,o, color = 'gray', alpha=0.5)
ax2.plot(o6,o, color = 'gray', alpha=0.5)
ax2.plot(o7,o, color = 'gray', alpha=0.5)
ax2.plot(o8,o, color = 'gray', alpha=0.5)
ax2.plot(o9,o, color = 'gray', alpha=0.5)
ax2.errorbar(x1, y1, yerr=er1, fmt='-o', ls='--', capsize=7, elinewidth=3, label='akryshtal 10', alpha=0.7)
ax2.errorbar(k1, z1, yerr=er42, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='ysu 10')
ax2.errorbar(l1, p1, yerr=er22, fmt='-o', ls='--', capsize=7, elinewidth=3,  alpha=0.7, label='mbe 10 av')
ax2.errorbar(s1, t1, yerr=er32, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='kb 10 av')
ax2.errorbar(j1, m1, yerr=er12, fmt='-o', ls='--', capsize=7, elinewidth=3, alpha=0.7, label='mba 10 av')
ax2.set_ylabel('SD,°')
ax2.set_xlabel('angles, °')

ax2.legend()

plt.savefig('all_0_10_sd_4.png')
plt.show()
