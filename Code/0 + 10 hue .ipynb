# %%
def zerolistmaker(n):
    listofzeros = [0] * n
    return listofzeros

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt
file_location = "hue.xlsx"

workbook = xlrd.open_workbook(file_location)

first_sheet = workbook.sheet_by_index(1)

# print(first_sheet)
a = [360]*11
x = [first_sheet.cell_value(i, 2) for i in range(1,191,1)] + a
y = [first_sheet.cell_value(i, 3) for i in range(1,191,1)] + [first_sheet.cell_value(i, 3) for i in range(96,107,1)]
x1 = [first_sheet.cell_value(i, 2) for i in range(193,383,1)] + a
y1 = [first_sheet.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet.cell_value(i, 3) for i in range(288,299,1)]

yerr_pos = [first_sheet.cell_value(i, 2) for i in range(first_sheet.ncols)]
yerr_neg = [first_sheet.cell_value(i, 3) for i in range(first_sheet.ncols)]

# yerr_pos = [first_sheet.cell_value(i, 2) for i in range(first_sheet.ncols)]
# yerr_neg = [first_sheet.cell_value(i, 3) for i in range(first_sheet.ncols)]

print(x[108])
plt.axis([-5,365,-15,15])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x,y,'o',label='akryshtal 0')
plt.plot(x1,y1,'o',label='akryshtal 10')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise')
plt.legend()
plt.savefig('ak_0_10.png')
# Out:
# 45.0

# %%
file_location1 = "hueysu.xlsx"

workbook1 = xlrd.open_workbook(file_location1)

first_sheet1 = workbook1.sheet_by_index(0)


k = [first_sheet1.cell_value(i, 2) for i in range(1,176,1)] + a
z = [first_sheet1.cell_value(i, 3) for i in range(1,176,1)] + [first_sheet1.cell_value(i, 3) for i in range(80,91,1)]
k1 = [first_sheet1.cell_value(i, 2) for i in range(178, 369,1)] + a
z1 = [first_sheet1.cell_value(i, 3) for i in range(178, 369,1)] + [first_sheet1.cell_value(i, 3) for i in range(274, 285,1)] 
yerr_pos = [first_sheet1.cell_value(i, 2) for i in range(first_sheet1.ncols)]
yerr_neg = [first_sheet1.cell_value(i, 3) for i in range(first_sheet1.ncols)]

print(k[91])
plt.axis([-5,365,-15,15])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(k,z,'o',label='ysu 0')
plt.plot(k1,z1,'o',label='ysu 10')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise')
plt.legend()
plt.savefig('ysu_0_10.png')
# Out:
# 0.0

# %%
file_location2 = "huembe.xlsx"

workbook2 = xlrd.open_workbook(file_location2)

first_sheet2 = workbook2.sheet_by_index(0)

b = [360]*12
l = [first_sheet2.cell_value(i, 2) for i in range(1,190,1)] + a
p = [first_sheet2.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet2.cell_value(i, 3) for i in range(97,108,1)]
l1 = [first_sheet2.cell_value(i, 2) for i in range(193,383,1)] + b
p1 = [first_sheet2.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet2.cell_value(i, 3) for i in range(288,300,1)]
yerr_pos = [first_sheet2.cell_value(i, 2) for i in range(first_sheet2.ncols)]
yerr_neg = [first_sheet2.cell_value(i, 3) for i in range(first_sheet2.ncols)]

print(l[96], l[107])
plt.axis([-5,365,-15,15])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(l,p,'o',label='mbengala 0')
plt.plot(l1,p1,'o',label='mbengala 10')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise')
plt.legend()
plt.savefig('mbe_0_10.png')
# Out:
# 0.0 0.0

# %%
file_location3 = "huekb.xlsx"

workbook3 = xlrd.open_workbook(file_location3)

first_sheet3 = workbook3.sheet_by_index(0)

b = [360]*10
s = [first_sheet3.cell_value(i, 2) for i in range(1,190,1)] + b
t = [first_sheet3.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet3.cell_value(i, 3) for i in range(1,11,1)] 
c = [360]*10
s1 = [first_sheet3.cell_value(i, 2) for i in range(193,383,1)] + a
t1 = [first_sheet3.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet3.cell_value(i, 3) for i in range(290,301,1)]

yerr_pos = [first_sheet3.cell_value(i, 2) for i in range(first_sheet3.ncols)]
yerr_neg = [first_sheet3.cell_value(i, 3) for i in range(first_sheet3.ncols)]

print(s[1], s[11])
plt.axis([-5,365,-15,15])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(s,t,'o', label='kbracher 0')
plt.plot(s1,t1,'o', label='kbracher 10')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('0 + 10noise')
plt.legend()
plt.savefig('kb_0_10.png')
# Out:
# 0.0 0.0

# %%
file_location4 = "huemba.xlsx"

workbook4 = xlrd.open_workbook(file_location4)

first_sheet4 = workbook4.sheet_by_index(0)

b = [360]*12
j = [first_sheet4.cell_value(i, 2) for i in range(1,190,1)] + a
m = [first_sheet4.cell_value(i, 3) for i in range(1,190,1)] + [first_sheet4.cell_value(i, 3) for i in range(97,108,1)]
j1 = [first_sheet4.cell_value(i, 2) for i in range(193,383,1)] + b
m1= [first_sheet4.cell_value(i, 3) for i in range(193,383,1)] + [first_sheet4.cell_value(i, 3) for i in range(288,300,1)]
yerr_pos = [first_sheet4.cell_value(i, 2) for i in range(first_sheet4.ncols)]
yerr_neg = [first_sheet4.cell_value(i, 3) for i in range(first_sheet4.ncols)]


plt.axis([-5,365,-15,15])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(j,m,'o', label='mbayer 0')
plt.plot(j1,m1,'o', label='mbayer 10')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('0 + 10 noise')
plt.legend()
plt.savefig('mba_0_10.png')

# %%
plt.figure(figsize=(15, 15))
plt.axis([-5,365,-25,25])
o = np.linspace(-25,25)
o1 = zerolistmaker(len(o))
o2 = [45]*len(o)
o3 = [90]*len(o)
o4 = [135]*len(o)
o5 = [180]*len(o)
o6 = [225]*len(o)
o7 = [270]*len(o)
o8 = [315]*len(o)
o9 = [360]*len(o)
g= np.linspace(-5,365)
h=zerolistmaker(len(g))
plt.plot(g, h, color = 'gray')
plt.plot(o1,o, color = 'gray')
plt.plot(o2,o, color = 'gray')
plt.plot(o3,o, color = 'gray')
plt.plot(o4,o, color = 'gray')
plt.plot(o5,o, color = 'gray')
plt.plot(o6,o, color = 'gray')
plt.plot(o7,o, color = 'gray')
plt.plot(o8,o, color = 'gray')
plt.plot(o9,o, color = 'gray')
plt.plot(x, y,'o', label='akryshtal 0', color = 'blue')
plt.plot(k,z, 'o', label='ysu 0', color = 'blue')
plt.plot(l,p, 'o', label='mbengala 0', color = 'blue')
plt.plot(s,t, 'o', label='kbracher 0', color = 'blue')
plt.plot(j, m, 'o', label='mbayer 0', color = 'blue')
plt.plot(x1, y1,'o', label='akryshtal 10', color = 'red')
plt.plot(k1,z1, 'o', label='ysu 10', color = 'red')
plt.plot(l1,p1, 'o', label='mbengala 10', color = 'red')
plt.plot(s1,t1, 'o', label='kbracher 10', color = 'red')
plt.plot(j1, m1, 'o', label='mbayer 10', color = 'red')
plt.ylabel('delta, °')
plt.xlabel('angles, °')
plt.title('All subjects with 0 + 10 noise')
plt.legend()
plt.savefig('all_0_10__.png')


plt.show()
